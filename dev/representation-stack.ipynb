# %%
pip install napari-bbox
# Out:
# Requirement already satisfied: napari-bbox in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (0.0.9)
# Requirement already satisfied: numpy in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (2.0.2)
# Requirement already satisfied: qtpy in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (2.4.3)
# Requirement already satisfied: napari>=0.4.15 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (0.6.0)
# Requirement already satisfied: packaging in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (24.2)
# Requirement already satisfied: pandas in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (2.2.3)
# Requirement already satisfied: npe2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (0.7.8)
# Requirement already satisfied: vispy in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-bbox) (0.14.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (1.4.4)
# Requirement already satisfied: app-model<0.4.0,>=0.3.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.3.1)
# Requirement already satisfied: cachey>=0.2.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.2.1)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (2025.4.26)
# Requirement already satisfied: dask>=2021.10.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (2025.4.1)
# Requirement already satisfied: imageio!=2.22.1,>=2.20 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (2.37.0)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (4.23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.4)
# Requirement already satisfied: magicgui>=0.7.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.10.0)
# Requirement already satisfied: napari-console>=0.1.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.1.3)
# Requirement already satisfied: napari-plugin-engine>=0.1.9 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.2.0)
# Requirement already satisfied: napari-svg>=0.1.8 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.2.1)
# Requirement already satisfied: numpydoc>=1.0.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (1.8.0)
# Requirement already satisfied: Pillow>=9.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (11.1.0)
# Requirement already satisfied: pint>=0.17 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.24.4)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (7.0.0)
# Requirement already satisfied: psygnal>=0.5.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.13.0)
# Requirement already satisfied: pydantic>=2.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (2.11.4)
# Requirement already satisfied: pygments>=2.6.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (2.19.1)
# Requirement already satisfied: PyOpenGL>=3.1.5 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (3.1.9)
# Requirement already satisfied: pywin32 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (310)
# Requirement already satisfied: PyYAML>=6.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (6.0.2)
# Requirement already satisfied: scikit-image>=0.19.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (0.25.2)
# Requirement already satisfied: scipy>=1.10.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (1.15.2)
# Requirement already satisfied: superqt>=0.6.7 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (0.7.3)
# Requirement already satisfied: tifffile>=2022.7.28 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (2025.3.30)
# Requirement already satisfied: toolz>=0.11.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (1.0.0)
# Requirement already satisfied: tqdm>=4.56.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.6.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (4.13.1)
# Requirement already satisfied: wrapt>=1.13.3 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari>=0.4.15->napari-bbox) (1.17.2)
# Requirement already satisfied: build>=1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from npe2->napari-bbox) (1.2.2.post1)
# Requirement already satisfied: rich in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from npe2->napari-bbox) (14.0.0)
# Requirement already satisfied: tomli-w in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from npe2->napari-bbox) (1.2.0)
# Requirement already satisfied: typer in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from npe2->napari-bbox) (0.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pandas->napari-bbox) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pandas->napari-bbox) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pandas->napari-bbox) (2025.2)
# Requirement already satisfied: freetype-py in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from vispy->napari-bbox) (2.5.1)
# Requirement already satisfied: hsluv in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from vispy->napari-bbox) (5.0.4)
# Requirement already satisfied: kiwisolver in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from vispy->napari-bbox) (1.4.8)
# Requirement already satisfied: in-n-out>=0.1.5 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from app-model<0.4.0,>=0.3.0->napari>=0.4.15->napari-bbox) (0.2.1)
# Requirement already satisfied: pydantic-compat>=0.1.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from app-model<0.4.0,>=0.3.0->napari>=0.4.15->napari-bbox) (0.1.2)
# Requirement already satisfied: pyproject_hooks in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from build>=1->npe2->napari-bbox) (1.2.0)
# Requirement already satisfied: colorama in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from build>=1->npe2->napari-bbox) (0.4.6)
# Requirement already satisfied: heapdict in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from cachey>=0.2.1->napari>=0.4.15->napari-bbox) (1.0.1)
# Requirement already satisfied: click>=8.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (8.2.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (8.7.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from jsonschema>=3.2.0->napari>=0.4.15->napari-bbox) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from jsonschema>=3.2.0->napari>=0.4.15->napari-bbox) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from jsonschema>=3.2.0->napari>=0.4.15->napari-bbox) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from jsonschema>=3.2.0->napari>=0.4.15->napari-bbox) (0.24.0)
# Requirement already satisfied: docstring-parser>=0.7 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from magicgui>=0.7.0->napari>=0.4.15->napari-bbox) (0.16)
# Requirement already satisfied: IPython>=7.7.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (9.0.2)
# Requirement already satisfied: ipykernel>=5.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (6.29.5)
# Requirement already satisfied: qtconsole!=4.7.6,!=5.4.2,>=4.5.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (5.6.1)
# Requirement already satisfied: sphinx>=6 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (8.2.3)
# Requirement already satisfied: tabulate>=0.8.10 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (0.9.0)
# Requirement already satisfied: platformdirs>=2.1.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pint>=0.17->napari>=0.4.15->napari-bbox) (4.3.7)
# Requirement already satisfied: flexcache>=0.3 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pint>=0.17->napari>=0.4.15->napari-bbox) (0.3)
# Requirement already satisfied: flexparser>=0.4 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pint>=0.17->napari>=0.4.15->napari-bbox) (0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pydantic>=2.2.0->napari>=0.4.15->napari-bbox) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pydantic>=2.2.0->napari>=0.4.15->napari-bbox) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pydantic>=2.2.0->napari>=0.4.15->napari-bbox) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->napari-bbox) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from scikit-image>=0.19.1->scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (3.4.2)
# Requirement already satisfied: pooch>=1.6.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (1.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from rich->npe2->napari-bbox) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from typer->npe2->napari-bbox) (1.5.4)
# Requirement already satisfied: zipp>=3.20 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from importlib_metadata>=4.13.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (1.8.13)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from ipykernel>=5.2.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (5.14.3)
# Requirement already satisfied: decorator in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (3.0.50)
# Requirement already satisfied: stack_data in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.6.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->npe2->napari-bbox) (0.1.2)
# Requirement already satisfied: locket in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from partd>=1.4.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari>=0.4.15->napari-bbox) (1.0.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (2.32.3)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (3.1.6)
# Requirement already satisfied: docutils<0.22,>=0.20 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (3.0.1)
# Requirement already satisfied: babel>=2.13 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (3.1.0)
# Requirement already satisfied: pyconify>=0.1.4 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from superqt[iconify]>=0.6.1->magicgui>=0.7.0->napari>=0.4.15->napari-bbox) (0.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from Jinja2>=3.1->sphinx>=6->numpydoc>=1.0.0->napari>=0.4.15->napari-bbox) (3.0.2)
# Requirement already satisfied: wcwidth in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari>=0.4.15->napari-bbox) (2.4.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\michael forsthofer\coding\rgc_reconstruction\.venv\lib\site-packages (from stack_data->IPython>=7.7.0->napari-console>=0.1.1->napari>=0.4.15->napari-bbox) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import napari
import tifffile
import numpy as np

# === Load Image ===
filename = r"D:\Box Sync\confocal\nanodiamonds\h2.tif"
image = tifffile.imread(filename)
z, y, x = image.shape
size_um = np.array([z, y, x]) * scale

# === Define cube corner coordinates (in physical space) ===
# Format: [Z, Y, X]
corners = np.array([
    [0, 0, 0],                          # 0
    [0, 0, size_um[2]],                # 1
    [0, size_um[1], 0],                # 2
    [0, size_um[1], size_um[2]],       # 3
    [size_um[0], 0, 0],                # 4
    [size_um[0], 0, size_um[2]],       # 5
    [size_um[0], size_um[1], 0],       # 6
    [size_um[0], size_um[1], size_um[2]]  # 7
])

# === Define edges as lines between corners ===
edge_indices = [
    [0, 1], [1, 3], [3, 2], [2, 0],     # bottom face
    [4, 5], [5, 7], [7, 6], [6, 4],     # top face
    [0, 4], [1, 5], [2, 6], [3, 7]      # vertical edges
]

# Create list of line segments
lines = [[corners[i], corners[j]] for i, j in edge_indices]

# === Launch Napari viewer ===
viewer = napari.Viewer(ndisplay=3)

# Add the image with correct scaling
viewer.add_image(image, scale=scale, name='3D Image', colormap='red')

# Add wireframe cube as a shape layer
viewer.add_shapes(
    lines,
    shape_type='line',
    edge_color='white',
    edge_width=0.05,
    name='Bounding Box'
)
viewer.camera.angles = (7, 30, 15)  # (elevation, azimuth, roll) in degrees
napari.run()

# %%
import napari
import tifffile
import numpy as np


# === Load Image ===
filename = r"D:\Box Sync\confocal\nanodiamonds\nanobeads.tif"
image = tifffile.imread(filename)
z, y, x = image.shape
size_um = np.array([z, y, x]) * scale

# === Define cube corner coordinates (in physical space) ===
corners = np.array([
    [0, 0, 0],                          # 0
    [0, 0, size_um[2]],                # 1
    [0, size_um[1], 0],                # 2
    [0, size_um[1], size_um[2]],       # 3
    [size_um[0], 0, 0],                # 4
    [size_um[0], 0, size_um[2]],       # 5
    [size_um[0], size_um[1], 0],       # 6
    [size_um[0], size_um[1], size_um[2]]  # 7
])

# === Define edges as lines between corners ===
edge_indices = [
    [0, 1], [1, 3], [3, 2], [2, 0],     # bottom face
    [4, 5], [5, 7], [7, 6], [6, 4],     # top face
    [0, 4], [1, 5], [2, 6], [3, 7]      # vertical edges
]

# Create list of line segments
lines = [[corners[i], corners[j]] for i, j in edge_indices]

# === Ticks at 0, 5, 10 microns along each axis ===
tick_values = [0, 5, 10]

# X ticks (along +X, fixed Y and Z)
x_ticks = np.array([[0, 0, val] for val in tick_values if val <= size_um[2]])
x_labels = [f'{val} µm' for val in tick_values if val <= size_um[2]]

# Y ticks (along +Y, fixed X and Z)
y_ticks = np.array([[0, val, 0] for val in tick_values if val <= size_um[1]])
y_labels = [f'{val} µm' for val in tick_values if val <= size_um[1]]

# Z ticks (along +Z, fixed X and Y)
z_ticks = np.array([[val, 0, 0] for val in tick_values if val <= size_um[0]])
z_labels = [f'{val} µm' for val in tick_values if val <= size_um[0]]

# === Combine ticks and labels ===
tick_points = np.vstack([x_ticks, y_ticks, z_ticks])
tick_texts = x_labels + y_labels + z_labels

# === Launch Napari ===
viewer = napari.Viewer(ndisplay=3)

# Add image in red
viewer.add_image(image, scale=scale, name='3D Image', colormap='red')

# Add bounding box
viewer.add_shapes(
    lines,
    shape_type='line',
    edge_color='white',
    edge_width=0.2,
    name='Bounding Box'
)

viewer.add_points(
    tick_points,
    size=0.5,
    face_color='white',
    name='Scale Ticks'
)

# viewer.add_text(
#     tick_texts,
#     translation=tick_points,
#     anchor='center',
#     color='white',
#     text_size=8,
#     name='Tick Labels'
# )

napari.run()
